# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
#make regression.datset is used to create fake dataset

# %%
x,y = make_regression(n_samples=20,n_features=1,n_informative =1,n_targets=1,noise = 100,random_state=2)

# %%
#plotting dataset on a graph

# %%
plt.scatter(x,y)

# %%
#first training the model so that initially we get the values of actual parameters
#so that later on we can use

# %%
lr=LinearRegression()
lr.fit(x,y)
LinearRegression()
# Out:
# LinearRegression()

# %%
#getting the parameter values according the equation-> (mx+b)

# %%
#m value
#bvalue
m = lr.coef_
b=lr.intercept_

# %%
print(m)
print(b)
# Out:
# [57.03069586]
# -51.38704024529875

# %%
#now we will seee as we iterate to update the values of parameter how they move to local minima

# %%
#1stly we will see the study with respect to b parameter so we assume that m is sonstant at this 
#moment which we are going to take m =57.03

# %%
#let us 1st discuss how we actually perform gradient descent

# %%
#step1 : start with random value of b

# %%
#step 2 : in iterations (eg 500) or till b(new) -b(old) becomes very small, perform below step

# %%
#  b(bew) = b(old)- learningrate *   slope_of_function at particular value of parameter

# %%
#step 3 :finally we have got optimized value of our parameteer

# %%
b=50
plt.style.use('seaborn-v0_8-dark-palette')
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="#EA1179")
y_pred = m*x+b
plt.plot(x,y_pred,color='green')

# %%
learning_rate = 0.01
#changing parameter value in first iteration    ------itn1
#calculating slope

# %%
slope = -2*np.sum(y-57.03*np.ravel(x) - b)
step_size = slope*learning_rate

# %%
#updating value of b
b=b-step_size
print(b)
# Out:
# 9.445125640447138

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="#EA1179")
y_pred1 = m*x+b
plt.plot(x,y_pred1,color='green')

# %%
#changing parameter value in second ------------itn2
#calculating slope 
slope = -2*np.sum(y-57.03*np.ravel(x)-b)
step_size=slope*learning_rate

# %%
#updating value (b)
b= b-step_size
print(b)
# Out:
# -14.887798975284575

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="#EA1179")
y_pred2 = m*x + b
plt.plot(x,y_pred2,color='green')

# %%
#itn3
#cal slope 
slope = -2*np.sum(y-57.03*np.ravel(x)-b)
step_size = slope*learning_rate 
#updating value of b 
b= b-step_size
print(b)
# Out:
# -49.684270502574776

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="#EA1179")
y_pred3= m*x+b
plt.plot(x,y_pred3,color='green')

# %%
#itn3
#cal slope 
slope = -2*np.sum(y-57.03*np.ravel(x)-b)
step_size = slope*learning_rate 
#updating value of b 
b= b-step_size
print(b)
# Out:
# -46.656865353583896

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="#EA1170")
y_pred5=m*x+b
plt.plot(x,y_pred,color='#C51605')
plt.plot(x,y_pred,color='#0D1282')
plt.plot(x,y_pred,color='#E63923')
plt.plot(x,y_pred,color='#B22222')
plt.plot(x,y_pred,color='#D7263D')
plt.plot(x,y_pred,color='#A83232')

# %%
b=500
m=57.04
lr=0.01
epochs = int(input("no of epochs:"))
plt.figure(figsize=(10,6))
for i in range(epochs):
    slope=-2*np.sum(y-57.03*np.ravel(x)-b)
    step_size=slope*learning_rate
    b=b-step_size
    y_pred=m*x+b
    plt.plot(x,y_pred)
plt.scatter(x,y)
# Out:
# no of epochs: 50

# %%
class GDRegressor:
    def __init__(self, learningrate, epochs):
       self.m=100
       self.b=-120
       self.lr=learning_rate
       self.epochs=epochs
def fit(self,x,y):
    for i in range(self.epochs):
        slope_b = -2*np.sum(y-self.m*x.ravel()-self.b)
        loss_slope_m = -2*np.sum(y-self.m*x.ravel()-self.m)
        self.b = self.b - (self.lr * loss_slope_b)
        self.m=self.m-(self.lr*loss_slope_m)
print(self.m,self.b)
def predict(self, x):
    return self.m*x+self.b
lgd = GDRegressor(0.01,100)
lgd.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 13
#      11         self.b = self.b - (self.lr * loss_slope_b)
#      12         self.m=self.m-(self.lr*loss_slope_m)
# ---> 13 print(self.m,self.b)
#      14 def predict(self, x):
#      15     return self.m*x+self.b
#
# NameError: name 'self' is not defined
